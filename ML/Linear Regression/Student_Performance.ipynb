# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Student_Performance.csv")

# %%
data
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
# Checking missing values

data.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
data.shape
# Out:
# (10000, 6)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
data[["Hours Studied", "Performance Index"]].head(20)
# Out:
#     Hours Studied  Performance Index
# 0               7               91.0
# 1               4               65.0
# 2               8               45.0
# 3               5               36.0
# 4               7               66.0
# 5               3               61.0
# 6               7               63.0
# 7               8               42.0
# 8               5               61.0
# 9               4               69.0
# 10              8               84.0
# 11              8               73.0
# 12              3               27.0
# 13              6               33.0
# 14              5               68.0
# 15              2               43.0
# 16              8               67.0
# 17              6               70.0
# 18              2               30.0
# 19              5               63.0

# %%
plt.figure(figsize = (8,6))
sns.scatterplot(x = "Hours Studied", y= "Performance Index", data = data)
plt.xlabel ("Hours Studied")
plt.ylabel ("Performance Index")
plt.title ("Student Performance by studies hour")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize = (8,6))
sns.histplot(x= "Sleep Hours", kde = True, data = data, bins = 11)
plt.title("Distribution of Sleep Hours")
plt.xlabel ("Sleep Hours")
plt.ylabel("Frequency")
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
data["Extracurricular Activities"].value_counts()
# Out:
# No     5052
# Yes    4948
# Name: Extracurricular Activities, dtype: int64

# %%
data[["Sleep Hours"]].value_counts()
# Out:
# Sleep Hours
# 8              1804
# 7              1676
# 6              1673
# 9              1622
# 4              1619
# 5              1606
# dtype: int64

# %%
sns.lineplot(x = "Previous Scores", y= "Performance Index", data = data)
plt.title ("Previous Score vs Performance Index")
plt.xlabel ("Previous Score")
plt.ylabel("Performance Index")
plt.show()

# %%
data[["Previous Scores", "Performance Index"]].mean()
# Out:
# Previous Scores      69.4457
# Performance Index    55.2248
# dtype: float64

# %%
data.corr()
# Out:
#                                   Hours Studied  Previous Scores  Sleep Hours  \
# Hours Studied                          1.000000        -0.012390     0.001245
# Previous Scores                       -0.012390         1.000000     0.005944
# Sleep Hours                            0.001245         0.005944     1.000000
# Sample Question Papers Practiced       0.017463         0.007888     0.003990
# Performance Index                      0.373730         0.915189     0.048106
#
#                                   Sample Question Papers Practiced  \
# Hours Studied                                             0.017463
# Previous Scores                                           0.007888
# Sleep Hours                                               0.003990
# Sample Question Papers Practiced                          1.000000
# Performance Index                                         0.043268
#
#                                   Performance Index
# ...

# %%
sns.heatmap(data.corr(), annot = True, cmap = "coolwarm", center = 0)
plt.title ("Correlation Matrix  HeatMap", fontsize = 15)
plt.show()

# %%
sns.pairplot(data)

# %%
data
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %% [markdown]
# # Splitting our data into x and y

# %%
x = data.drop(columns = "Performance Index")

# %%
x
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced
# ...

# %%
y = data["Performance Index"]

# %%
y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 10000, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_Extra_activities = LabelEncoder()

# %%
x["Extra_activities"] = le_Extra_activities.fit_transform(x["Extracurricular Activities"])

# %%
x
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
x = x.drop(["Extracurricular Activities"], axis = 1)

# %%
x
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9995              1               49            4
# 9996              7               64            8
# 9997              6               83            8
# 9998              9               97            7
# 9999              7               74            8
#
#       Sample Question Papers Practiced  Extra_activities
# 0                                    1                 1
# 1                                    2                 0
# 2                                    2                 1
# 3                                    2                 1
# 4                                    5                 0
# ...

# %% [markdown]
# # Train - Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (8000, 5)
# (2000, 5)
# (8000,)
# (2000,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(f"intercept is {model.intercept_}")
# Out:
# intercept is -34.075208225213416

# %% [markdown]
# The intercept of  (-34.075) In linear regression, the intercept represents the expected value of the dependent variable (y) when all independent variables (x) are equal to zero.
#
# - Interpretation:
#     The intercept of -34.075 means that: "If a student has:
#     - 0 hours studied
#     - 0 previous scores
#     - 0 extracurricular activities
#     - 0 sleep hours
#     - 0 simple question paper practiced
#
#  Their expected performance index would be -34.075

# %%
print(f"Coeffficient or Slope is {model.coef_}")
# Out:
# Coeffficient or Slope is [2.85191442 1.01886667 0.47682996 0.18776637 0.66530347]

# %%
x
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9995              1               49            4
# 9996              7               64            8
# 9997              6               83            8
# 9998              9               97            7
# 9999              7               74            8
#
#       Sample Question Papers Practiced  Extra_activities
# 0                                    1                 1
# 1                                    2                 0
# 2                                    2                 1
# 3                                    2                 1
# 4                                    5                 0
# ...

# %% [markdown]
# KEY FINDING
#
# - Hours studied has a significant positive impact on performance (β = 2.852)
# - Previous scores are a strong predictor of future performance (β = 1.019)
# - Sleep hours have a small positive effect on performance (β = 0.477)
# - Simple question paper practiced has a minimal positive effect on performance (β = 0.188).
# - Extracurricular activities have a moderate positive effect on performance (β = 0.665)

# %% [markdown]
# These findings suggest that:
#
# 1. Encouraging students to study regularly can improve academic outcomes.
# 2. Prior academic performance is a reliable indicator of future success.
# 3. Extracurricular activities can enhance student engagement and performance.
# 4. Adequate sleep hours contribute to better academic performance.
# 5. Practicing simple question papers can have a slight positive impact.

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([50.45128503, 53.09379171, 78.24502652, ..., 64.56863194,
#        25.89718776, 18.82598463])

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
mse = mean_squared_error(y_test, y_pred)

# %%
print (f"mean square error {mse}")
# Out:
# mean square error 4.105609215835833

# %%
# Calculating the error metrices

def eval_metrices (actual, pred):
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    rmse = np.sqrt(mean_squared_error(actual, pred))
    R2_score = r2_score(actual, pred)
    print ("Model testing Performance: ")
    print ("----------------------------")
    print (f"MAE \t\t: {mae}")
    print (f"r2_score \t: {R2_score}")
    print(f"MSE \t\t: {mse}")
    print(f"RMSE \t\t: {rmse}")

# %%
eval_metrices (y_test, y_pred)
# Out:
# Model testing Performance:
# ----------------------------
# MAE 		: 1.622970832971088
# r2_score 	: 0.9880686410711422
# MSE 		: 4.105609215835833
# RMSE 		: 2.0262302968408683

# %% [markdown]
# Interpretation:
#
# - R² (0.988): The model explains approximately 98.8% of the variance in student performance
# - MSE (4.106): The average squared difference between predicted and actual values is relatively low
# - RMSE (2.026): The square root of MSE, indicating a low average error
# - MAE (1.623): The average absolute difference between predicted and actual values is relatively low.

# %%
# Plotting the actual and predicted values

# %%
plt.scatter(y_test, y_pred, color = "blue", label = "Predicted vs Actual")
plt.title("Actual vs Predicted Values")
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()],color = "red", linewidth = 2)
plt.grid(True)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.show()

# %%
data
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...
